# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

# %%
data_a=sns.load_dataset('tips')

# %%
data_a.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data_a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data_a.shape
# Out:
# (244, 7)

# %%
data_a.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data_a.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data_a.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
data_a.value_counts('smoker')
# Out:
# smoker
# No     151
# Yes     93
# dtype: int64

# %%
data_a.value_counts('day')
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# dtype: int64

# %%
data_a.value_counts('size')
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# dtype: int64

# %%
data_a.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %% [markdown]
# # relplot and scatterplot

# %%
#plot a scatter plot betw total_bill and tips
sns.relplot(x='total_bill',y='tip',kind='scatter',data=data_a)

# %% [markdown]
# # The Hue parameter

# %%
sns.relplot(x='total_bill',y='tip',data=data_a,hue='smoker',kind='scatter')

# %%
data_a.value_counts('smoker')
#no smoker are more
# Out:
# smoker
# No     151
# Yes     93
# dtype: int64

# %% [markdown]
# # Style parameter

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter',hue='smoker',data=data_a,style='sex')

# %% [markdown]
# # The size parameter

# %%
sns.relplot(x='total_bill',y='tip',data=data_a,kind='scatter',hue='smoker',style='sex',size='size',sizes=(15,200))

# %% [markdown]
# Scatterplot function

# %%
sns.scatterplot(x='total_bill',y='tip',data=data_a,hue='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Plotting with categorical Data

# %% [markdown]
# ## Catplot Figure level function

# %% [markdown]
# ### 1.Categorical scatterplot

# %% [markdown]
# #### a. stripplot
# #### b. swarmplot

# %% [markdown]
# ## Categorical distribution plots

# %% [markdown]
# a.Boxplot
# b.violinplot

# %%
plt.style.use('fivethirtyeight')

# %%
tip=sns.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# x-- categorical data
#y-- numerical data

# %% [markdown]
# # Shift + tab = Doc

# %%
sns.catplot(x='day',y='tip',kind='strip',jitter=0,data=tip)

# %%
sns.catplot(x='day',y='tip',kind='swarm',data=tip)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day',y='tip',kind='swarm',hue='sex',data=tip)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # Boxplot

# %%
#univariate
sns.boxplot(tip['tip'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %%
sns.boxplot(tip['total_bill'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
#multivariate analysis
sns.catplot(x='day',y='total_bill',kind='box',data=tip)

# %%
sns.boxplot(x='day',y='total_bill',data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day',y='tip',kind='box',data=tip)

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='box',data=tip)

# %%
sns.catplot(x='day',y='tip',hue='sex',kind='box',data=tip)

# %%
sns.catplot(x='smoker',y='total_bill',hue='sex',kind='box',data=tip)

# %% [markdown]
# # Violine plots

# %%
# violine plots are method of plotting numerical data and combinition of 
#the box plot with a kemel density plot

# %%
sns.violinplot(tip['total_bill'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=tip)

# %%
sns.catplot(x='day',y='tip',kind='violin',hue='sex',data=tip)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',hue='sex',style='smoker',data=tip)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',hue='sex',split='True',data=tip)

# %% [markdown]
# # Barplot and countplot

# %%
sns.catplot(x='day',y='total_bill',kind='bar',data=tip)

# %%
sns.barplot(x='day',y='total_bill',data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='smoker',y='total_bill',kind='bar',data=tip)

# %%
sns.catplot(x='smoker',y='total_bill',hue='sex',kind='bar',color='yellow',data=tip)

# %%
sns.catplot(x='smoker',y='total_bill',kind='bar',hue='sex',estimator=np.mean,data=tip)

# %%
sns.catplot(x='sex',kind='count',data=tip
           )

# %%
sns.countplot(tip['smoker'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.catplot(x='sex',hue='smoker',kind='count',data=tip)

# %% [markdown]
# # Heatmaps
# #### a heatamap is a graphical representation of data where the individual values contained in a matrix are represented as colors

# %%
df=sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x=df.pivot_table(index='year',columns='month',values='passengers',aggfunc='sum')

# %%
x
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False,linewidth=0.5,annot=True,fmt='d')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False,linewidth=0.5,annot=True,fmt='d',cmap='viridis')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False,linewidth=0.5,annot=True,fmt='d',cmap='summer')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False,linewidth=0.5,annot=True,fmt='d',cmap='winter')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# # clustermap

# %%
sns.clustermap(x,z_score=0,annot=True,row_cluster=False,metric='correlation')

# %% [markdown]
# # Jointplot
# ## jointplot creates a multipanel figure that shows both the bivariate relationship between two variables along with the univariate distribution of each on separate axis
# ### scatterplots
# ### hexbin plots
# ### kdeplots
# ### regplot

# %%
sns.jointplot(x='total_bill',y='tip',data=tip)

# %%
sns.jointplot(x='total_bill',y='tip',kind='hex' ,data=tip)

# %%
sns.jointplot(x='total_bill',y='tip',kind='kde',data=tip)

# %%
sns.jointplot(x='total_bill',y='tip',kind='reg',data=tip)

# %% [markdown]
# # Pairplot
# pairplots are used to plot multiple pairwise distribution in a dataset. this
# creates a matrix of axes and shows the relationship for each pair of columns in dataframe. by default it is also draws the univariate distribution of each variable on the diagonal axes

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue="species")

# %% [markdown]
# # Distplot (distribution plot)
# Displots are used to do univariate anslysis on a continuous/numerical data
#
# Displot combines 3 things in one graph
#
# 1. Histogram
# 2. Kernel Density Estimation (PDF)
# 3. Rugplot

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].fillna(titanic['age'].mean(),inplace=True)

# %%
titanic.isnull().age.sum()
# Out:
# 0

# %% [markdown]
# ## Plotting Displot

# %%
sns.displot(titanic['age'],kde=True)

# %%
sns.displot(titanic['age'])

# %%
sns.displot(titanic['age'],bins=100,kde=False)

# %% [markdown]
# # Plotting only the KDE

# %%
sns.displot(titanic['age'],kind='kde')

# %% [markdown]
# # Plotting only Rugplot

# %%
sns.distplot(titanic['age'],rug=True)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic['age'],hist=False,kde=False,rug=True)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ## How to use the Distplot

# %%
sns.distplot(titanic[titanic['survived']==1]['age'])
sns.distplot(titanic[titanic['survived']==0]['age'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>
